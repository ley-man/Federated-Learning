# %%
# Import Libraries: torch and torchvision
# Note that torch and torchvision are not supported by python versions later than 3.9

from collections import OrderedDict
from typing import List, Tuple

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import CIFAR10

import flwr as fl
from flwr.common import Metrics

# %%
DEVICE = torch.device("cpu")  # Try "cuda" to train on GPU
print(
    f"Training on {DEVICE} using PyTorch {torch.__version__} and Flower {fl.__version__}"
)

# TODO- Install torch for CUDA
# Out:
# Training on cpu using PyTorch 1.13.1+cpu and Flower 1.3.0

# %%
CLASSES = (
    "plane",
    "car",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
    "truck",
)

# %%
NUM_CLIENTS = 10

# %%
BATCH_SIZE = 32


def load_datasets():
    # Download and transform CIFAR-10 (train and test)
    transform = transforms.Compose(
        [transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]
    )
    trainset = CIFAR10("./dataset", train=True, download=True, transform=transform)
    testset = CIFAR10("./dataset", train=False, download=True, transform=transform)

    # Split training set into 10 partitions to simulate the individual dataset
    partition_size = len(trainset) // NUM_CLIENTS
    lengths = [partition_size] * NUM_CLIENTS
    datasets = random_split(trainset, lengths, torch.Generator().manual_seed(42))

    # Split each partition into train/val and create DataLoader
    trainloaders = []
    valloaders = []
    for ds in datasets:
        len_val = len(ds) // 10  # 10 % validation set
        len_train = len(ds) - len_val
        lengths = [len_train, len_val]
        ds_train, ds_val = random_split(ds, lengths, torch.Generator().manual_seed(42))
        trainloaders.append(DataLoader(ds_train, batch_size=BATCH_SIZE, shuffle=True))
        valloaders.append(DataLoader(ds_val, batch_size=BATCH_SIZE))
    testloader = DataLoader(testset, batch_size=BATCH_SIZE)
    return trainloaders, valloaders, testloader


trainloaders, valloaders, testloader = load_datasets()
# Out:
# 0.0%
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./dataset\cifar-10-python.tar.gz
# 57.6%IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 100.0%
# Extracting ./dataset\cifar-10-python.tar.gz to ./dataset
# Files already downloaded and verified

# %%
images, labels = next(iter(trainloaders[0]))

# Reshape and convert images to a NumPy array
# matplotlib requires images with the shape (height, width, 3)
images = images.permute(0, 2, 3, 1).numpy()
# Denormalize
images = images / 2 + 0.5

# Create a figure and a grid of subplots
fig, axs = plt.subplots(4, 8, figsize=(12, 6))

# Loop over the images and plot them
for i, ax in enumerate(axs.flat):
    ax.imshow(images[i])
    ax.set_title(CLASSES[labels[i]])
    ax.axis("off")

# Show the plot
fig.tight_layout()
plt.show()

# %%
# Simple CNN model
class Net(nn.Module):
    def __init__(self) -> None:
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
# Train module
def train(net, trainloader, epochs: int, verbose=False):
    """Train the network on the training set."""
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters())
    net.train()
    for epoch in range(epochs):
        correct, total, epoch_loss = 0, 0, 0.0
        for images, labels in trainloader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = net(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            # Metrics
            epoch_loss += loss
            total += labels.size(0)
            correct += (torch.max(outputs.data, 1)[1] == labels).sum().item()
        epoch_loss /= len(trainloader.dataset)
        epoch_acc = correct / total
        if verbose:
            print(f"Epoch {epoch+1}: train loss {epoch_loss}, accuracy {epoch_acc}")

# %%
# Test module
def test(net, testloader):
    """Evaluate the network on the entire test set."""
    criterion = torch.nn.CrossEntropyLoss()
    correct, total, loss = 0, 0, 0.0
    net.eval()
    with torch.no_grad():
        for images, labels in testloader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = net(images)
            loss += criterion(outputs, labels).item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    loss /= len(testloader.dataset)
    accuracy = correct / total
    return loss, accuracy

# %%
trainloader = trainloaders[0]
valloader = valloaders[0]
net = Net().to(DEVICE)

for epoch in range(5):
    train(net, trainloader, 1)
    loss, accuracy = test(net, valloader)
    print(f"Epoch {epoch+1}: validation loss {loss}, accuracy {accuracy}")

loss, accuracy = test(net, testloader)
print(f"Final test set performance:\n\tloss {loss}\n\taccuracy {accuracy}")
# Out:
# Epoch 1: validation loss 0.0622531988620758, accuracy 0.286
# Epoch 2: validation loss 0.05704948472976685, accuracy 0.324
# Epoch 3: validation loss 0.05346247148513794, accuracy 0.358
# Epoch 4: validation loss 0.05115734577178955, accuracy 0.414
# Epoch 5: validation loss 0.04922646164894104, accuracy 0.468
# Final test set performance:
# 	loss 0.04817234276533127
# 	accuracy 0.441

# %%
def get_parameters(net) -> List[np.ndarray]:
    return [val.cpu().numpy() for _, val in net.state_dict().items()]


def set_parameters(net, parameters: List[np.ndarray]):
    params_dict = zip(net.state_dict().keys(), parameters)
    state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
    net.load_state_dict(state_dict, strict=True)

# %%
class FlowerClient(fl.client.NumPyClient):
    def __init__(self, net, trainloader, valloader):
        self.net = net
        self.trainloader = trainloader
        self.valloader = valloader

    def get_parameters(self, config):
        return get_parameters(self.net)

    def fit(self, parameters, config):
        set_parameters(self.net, parameters)
        train(self.net, self.trainloader, epochs=1)
        return get_parameters(self.net), len(self.trainloader), {}

    def evaluate(self, parameters, config):
        set_parameters(self.net, parameters)
        loss, accuracy = test(self.net, self.valloader)
        return float(loss), len(self.valloader), {"accuracy": float(accuracy)}

# %%
def client_fn(cid: str) -> FlowerClient:
    """Create a Flower client representing a single organization."""

    # Load model
    net = Net().to(DEVICE)

    # Load data (CIFAR-10)
    # Note: each client gets a different trainloader/valloader, so each client
    # will train and evaluate on their own unique data
    trainloader = trainloaders[int(cid)]
    valloader = valloaders[int(cid)]

    # Create a  single Flower client representing a single organization
    return FlowerClient(net, trainloader, valloader)

# %%
# Create FedAvg strategy
strategy = fl.server.strategy.FedAvg(
    fraction_fit=1.0,  # Sample 100% of available clients for training
    fraction_evaluate=0.5,  # Sample 50% of available clients for evaluation
    min_fit_clients=10,  # Never sample less than 10 clients for training
    min_evaluate_clients=5,  # Never sample less than 5 clients for evaluation
    min_available_clients=10,  # Wait until all 10 clients are available
)

# Specify client resources if you need GPU (defaults to 1 CPU and 0 GPU)
client_resources = None
if DEVICE.type == "cuda":
    client_resources = {"num_gpus": 1}

# Start simulation
fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=NUM_CLIENTS,
    config=fl.server.ServerConfig(num_rounds=5),
    strategy=strategy,
    client_resources=client_resources,
)
# Out:
# INFO flwr 2023-02-16 12:08:22,805 | app.py:145 | Starting Flower simulation, config: ServerConfig(num_rounds=5, round_timeout=None)
# 2023-02-16 12:08:49,466	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# INFO flwr 2023-02-16 12:08:52,376 | app.py:179 | Flower VCE: Ray initialized with resources: {'memory': 5373507995.0, 'CPU': 16.0, 'object_store_memory': 2686753996.0, 'node:127.0.0.1': 1.0, 'GPU': 1.0}
# INFO flwr 2023-02-16 12:08:52,383 | server.py:86 | Initializing global parameters
# INFO flwr 2023-02-16 12:08:52,383 | server.py:270 | Requesting initial parameters from one random client
# INFO flwr 2023-02-16 12:08:54,170 | server.py:274 | Received initial parameters from one random client
# INFO flwr 2023-02-16 12:08:54,170 | server.py:88 | Evaluating initial parameters
# INFO flwr 2023-02-16 12:08:54,170 | server.py:101 | FL starting
# DEBUG flwr 2023-02-16 12:08:54,170 | server.py:215 | fit_round 1: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-02-16 12:09:05,705 | server.py:229 | fit_round 1 received 10 results and 0 failures
# WARNING flwr 2023-02-16 12:09:05,725 | fedavg.py:242 | No fit_metrics_aggregation_fn provided
# DEBUG flwr 2023-02-16 12:09:05,726 | server.py:165 | evaluate_round 1: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-02-16 12:09:09,979 | server.py:179 | evaluate_round 1 received 5 results and 0 failures
# WARNING flwr 2023-02-16 12:09:09,980 | fedavg.py:273 | No evaluate_metrics_aggregation_fn provided
# DEBUG flwr 2023-02-16 12:09:09,981 | server.py:215 | fit_round 2: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-02-16 12:09:19,954 | server.py:229 | fit_round 2 received 10 results and 0 failures
# DEBUG flwr 2023-02-16 12:09:19,972 | server.py:165 | evaluate_round 2: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-02-16 12:09:23,703 | server.py:179 | evaluate_round 2 received 5 results and 0 failures
# DEBUG flwr 2023-02-16 12:09:23,703 | server.py:215 | fit_round 3: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-02-16 12:09:34,713 | server.py:229 | fit_round 3 received 10 results and 0 failures
# DEBUG flwr 2023-02-16 12:09:34,732 | server.py:165 | evaluate_round 3: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-02-16 12:09:38,878 | server.py:179 | evaluate_round 3 received 5 results and 0 failures
# DEBUG flwr 2023-02-16 12:09:38,878 | server.py:215 | fit_round 4: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-02-16 12:09:48,276 | server.py:229 | fit_round 4 received 10 results and 0 failures
# DEBUG flwr 2023-02-16 12:09:48,291 | server.py:165 | evaluate_round 4: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-02-16 12:09:52,203 | server.py:179 | evaluate_round 4 received 5 results and 0 failures
# DEBUG flwr 2023-02-16 12:09:52,218 | server.py:215 | fit_round 5: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-02-16 12:10:01,989 | server.py:229 | fit_round 5 received 10 results and 0 failures
# DEBUG flwr 2023-02-16 12:10:02,004 | server.py:165 | evaluate_round 5: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-02-16 12:10:05,925 | server.py:179 | evaluate_round 5 received 5 results and 0 failures
# INFO flwr 2023-02-16 12:10:05,925 | server.py:144 | FL finished in 71.76196049999999
# INFO flwr 2023-02-16 12:10:05,925 | app.py:202 | app_fit: losses_distributed [(1, 0.06280230159759521), (2, 0.055945844745635985), (3, 0.052776612520217904), (4, 0.050296778297424315), (5, 0.04782732267379761)]
# INFO flwr 2023-02-16 12:10:05,925 | app.py:203 | app_fit: metrics_distributed {}
# INFO flwr 2023-02-16 12:10:05,925 | app.py:204 | app_fit: losses_centralized []
# INFO flwr 2023-02-16 12:10:05,925 | app.py:205 | app_fit: metrics_centralized {}
# History (loss, distributed):
# 	round 1: 0.06280230159759521
# 	round 2: 0.055945844745635985
# 	round 3: 0.052776612520217904
# 	round 4: 0.050296778297424315
# 	round 5: 0.04782732267379761

# %%
def weighted_average(metrics: List[Tuple[int, Metrics]]) -> Metrics:
    # Multiply accuracy of each client by number of examples used
    accuracies = [num_examples * m["accuracy"] for num_examples, m in metrics]
    examples = [num_examples for num_examples, _ in metrics]

    # Aggregate and return custom metric (weighted average)
    return {"accuracy": sum(accuracies) / sum(examples)}# Create FedAvg strategy

# %%
strategy = fl.server.strategy.FedAvg(
    fraction_fit=1.0,
    fraction_evaluate=0.5,
    min_fit_clients=10,
    min_evaluate_clients=5,
    min_available_clients=10,
    evaluate_metrics_aggregation_fn=weighted_average,  # <-- pass the metric aggregation function
)

# Start simulation
fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=NUM_CLIENTS,
    config=fl.server.ServerConfig(num_rounds=5),
    strategy=strategy,
    client_resources=client_resources,
)
# Out:
# INFO flwr 2023-02-16 12:10:32,063 | app.py:145 | Starting Flower simulation, config: ServerConfig(num_rounds=5, round_timeout=None)
# 2023-02-16 12:10:38,593	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# INFO flwr 2023-02-16 12:10:41,760 | app.py:179 | Flower VCE: Ray initialized with resources: {'memory': 4861285172.0, 'object_store_memory': 2430642585.0, 'GPU': 1.0, 'node:127.0.0.1': 1.0, 'CPU': 16.0}
# INFO flwr 2023-02-16 12:10:41,760 | server.py:86 | Initializing global parameters
# INFO flwr 2023-02-16 12:10:41,760 | server.py:270 | Requesting initial parameters from one random client
# INFO flwr 2023-02-16 12:10:43,649 | server.py:274 | Received initial parameters from one random client
# INFO flwr 2023-02-16 12:10:43,649 | server.py:88 | Evaluating initial parameters
# INFO flwr 2023-02-16 12:10:43,649 | server.py:101 | FL starting
# DEBUG flwr 2023-02-16 12:10:43,649 | server.py:215 | fit_round 1: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-02-16 12:10:54,683 | server.py:229 | fit_round 1 received 10 results and 0 failures
# WARNING flwr 2023-02-16 12:10:54,710 | fedavg.py:242 | No fit_metrics_aggregation_fn provided
# DEBUG flwr 2023-02-16 12:10:54,715 | server.py:165 | evaluate_round 1: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-02-16 12:10:58,803 | server.py:179 | evaluate_round 1 received 5 results and 0 failures
# DEBUG flwr 2023-02-16 12:10:58,803 | server.py:215 | fit_round 2: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-02-16 12:11:08,767 | server.py:229 | fit_round 2 received 10 results and 0 failures
# DEBUG flwr 2023-02-16 12:11:08,796 | server.py:165 | evaluate_round 2: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-02-16 12:11:12,290 | server.py:179 | evaluate_round 2 received 5 results and 0 failures
# DEBUG flwr 2023-02-16 12:11:12,290 | server.py:215 | fit_round 3: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-02-16 12:11:23,239 | server.py:229 | fit_round 3 received 10 results and 0 failures
# DEBUG flwr 2023-02-16 12:11:23,258 | server.py:165 | evaluate_round 3: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-02-16 12:11:27,087 | server.py:179 | evaluate_round 3 received 5 results and 0 failures
# DEBUG flwr 2023-02-16 12:11:27,103 | server.py:215 | fit_round 4: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-02-16 12:11:38,093 | server.py:229 | fit_round 4 received 10 results and 0 failures
# DEBUG flwr 2023-02-16 12:11:38,111 | server.py:165 | evaluate_round 4: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-02-16 12:11:41,628 | server.py:179 | evaluate_round 4 received 5 results and 0 failures
# DEBUG flwr 2023-02-16 12:11:41,628 | server.py:215 | fit_round 5: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-02-16 12:11:50,984 | server.py:229 | fit_round 5 received 10 results and 0 failures
# DEBUG flwr 2023-02-16 12:11:51,016 | server.py:165 | evaluate_round 5: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-02-16 12:11:54,986 | server.py:179 | evaluate_round 5 received 5 results and 0 failures
# INFO flwr 2023-02-16 12:11:54,986 | server.py:144 | FL finished in 71.34460450000006
# INFO flwr 2023-02-16 12:11:54,986 | app.py:202 | app_fit: losses_distributed [(1, 0.0639144829273224), (2, 0.053996754074096674), (3, 0.05090780892372131), (4, 0.0490133309841156), (5, 0.048484656095504765)]
# INFO flwr 2023-02-16 12:11:54,986 | app.py:203 | app_fit: metrics_distributed {'accuracy': [(1, 0.2912), (2, 0.37), (3, 0.4064), (4, 0.43479999999999996), (5, 0.44560000000000005)]}
# INFO flwr 2023-02-16 12:11:54,986 | app.py:204 | app_fit: losses_centralized []
# INFO flwr 2023-02-16 12:11:54,986 | app.py:205 | app_fit: metrics_centralized {}
# History (loss, distributed):
# 	round 1: 0.0639144829273224
# 	round 2: 0.053996754074096674
# 	round 3: 0.05090780892372131
# 	round 4: 0.0490133309841156
# 	round 5: 0.048484656095504765
# History (metrics, distributed):
# {'accuracy': [(1, 0.2912), (2, 0.37), (3, 0.4064), (4, 0.43479999999999996), (5, 0.44560000000000005)]}
